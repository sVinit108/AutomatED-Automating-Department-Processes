# %%
import pandas as pd
import matplotlib.pyplot as plt
from pymongo import MongoClient

client = MongoClient("mongodb+srv://rblfinalproject:automated141633@automatedcluster.yegmx7e.mongodb.net/") 
db = client["SIS"]  
collection = db["SDP"]  

cursor = collection.find({})

df = pd.DataFrame(list(cursor))

# %%
df1 = df.copy()
df11=df1.groupby('branch_div')['attendace'].sum()
df11.plot(kind='bar',figsize=(10,5),title='Branch-wise Attendance',color='pink')
plt.savefig(r'D:\Vinit Sharma\Comps\Academics\RBL\project_ui\static\sdp-attendance.png')
